# %% [markdown]
# # Aufgabe 1: Fachlich begründete Bewertung und Vergleich von Open Data Portale
#
# ## Mannheim Open Data Portal
#
# **Verfügbare Datensätze:**
# Das Mannheim Open Data Portal bietet eine breite Auswahl an Datensätzen, darunter Klimadaten, Bevölkerungsstatistiken, Wahlergebnisse, Stadtrecht und Besucherzahlen von Sport- und Bädern. Diese Daten sind hauptsächlich im CSV-Format verfügbar, aber auch JSON-Dateien, Excel-Tabellen und geografische Dateiformate sind vertreten.
#
# **Verfügbare Datenformate:**
# Die Daten sind hauptsächlich als CSV-Dateien verfügbar, was sie leicht zugänglich und verarbeitbar macht. Zusätzlich stehen JSON-Dateien, Excel-Tabellen und verschiedene geografische Dateiformate zur Verfügung.
#
# **Technisch nutzbare Schnittstellen:**
# Das Portal bietet eine gut dokumentierte API, die über [dieses Link](https://web.archive.org/web/20240714141225/https://mannheim.opendatasoft.com/api/explore/v2.1/console) frei öffentlich zugänglich ist. Die API ermöglicht den einfachen Abruf einzelner Datensätze sowie ganzer Kataloge. Zum Beispiel  der Datensatz zu den Renzstraße Eco-Counter-Daten welche gut eingesehen werden kann.
# (https://mannheim.opendatasoft.com/explore/dataset/renzstr-eco-counter-daten/api/)
#
# **Durchsuchbarkeit und Navigation:**
# Die Navigation ist durchschnittlich, der Aufbau nachvollziehbar, aber das Design nicht sehr benutzerfreundlich. Filtern und Durchsuchen der Datensätze ist mit wenigen Klicks möglich, was primär das Wichtigste ist.
#
# **Automatisierte Abfrage:**
# Die API ist gut strukturiert und dokumentiert, was die automatisierte Abfrage der Daten erleichtert. Sowohl einzelne Datensätze als auch ganze Kataloge können effizient abgerufen werden.
#
# **Datenabruf:**
# Die Datensätze können über den Reiter "Exporte" leicht navigiert und heruntergeladen werden. Bevor man Zugang erhält, müssen die AGBs akzeptiert werden.
#
# **Datenbeschreibung und -dokumentation:**
# Die Datenbeschreibung ist minimalistisch, enthält aber wichtige Metadaten wie Timestamps. Visualisierungen und Karten sind eingebunden, was die Analyse erleichtert.
# Außerdem ein explizieter Verweis auf eine API-Dokumentation. Sehr gut. <br>[Link zur Dokumentation](https://web.archive.org/web/20240530192115/https://help.opendatasoft.com/apis/ods-explore-v2/explore_v2.1.html#section/Getting-Started/Step-3:-Build-your-request)
#
# **Verbesserungsvorschläge:**
# Eine modernere Navigation könnte die Benutzerfreundlichkeit erhöhen.
#
# **Nutzbare Formate für die automatisierte Verarbeitung:**
# CSV und JSON sind besonders gut geeignet für eine automatische Automatisierung. CSV-Dateien sind weit verbreitet und einfach zu handhaben, JSON-Dateien sind für webbasierte Anwendungen nützlich.
#
# **Quelle:**<br>
# [Mannheim Open Data Portal](https://mannheim.opendatasoft.com/explore/?sort=modified)<br>
# [Mannheim Open Data Portal Web Archive](https://web.archive.org/web/20240714142422/https://mannheim.opendatasoft.com/explore/?sort=modified)
#
# ## Daten-BW Portal
#
# **Verfügbare Datensätze:**
# Das Daten-BW Portal bietet eine Vielzahl von Datensätzen in Kategorien wie Bevölkerung, Gesundheit, Umwelt und Mobilität. Die Daten sind in Formaten wie CSV, XLSX, JSON und WMS verfügbar.
#
# **Verfügbare Datenformate:**
# Die Daten sind hauptsächlich im CSV-Format vorhanden, zusätzlich werden Excel-Tabellen, JSON-Dateien und geografische Formate wie WFS_SRVC und WMS_SRVC angeboten.
#
# **Technisch nutzbare Schnittstellen:**
# APIs sind verfügbar, jedoch aufgrund der Sammlung von kommunalen und städtischen Datensätzen weniger effizient als direkte Zugriffe. Dies kann die Anbindung an BI-Systeme erschweren.
#
# **Durchsuchbarkeit und Navigation:**
# Die Navigation ist gut strukturiert und das Design modern. Die Datensätze können leicht nach verschiedenen Themen sortiert und durchsucht werden.
#
# **Automatisierte Abfrage:**
# Die automatisierte Abfrage ist komplizierter, da ein direkter Zugriff oft effizienter wäre. Dennoch bietet das Portal eine gute Übersicht über verschiedene Datensätze.
#
# **Datenabruf:**
# Der Abruf der Datensätze erfordert mehrere Klicks, da die Daten von verschiedenen Portalen zusammengetragen werden. Manchmal ist sogar nötig direkt auf das Open Data Portal der Datenanbietenden zu gehen.
#
# **Datenbeschreibung und -dokumentation:**
# Die Datenbeschreibung ist minimalistisch, enthält aber wichtige Metadaten wie Timestamps.
#
# **Verbesserungsvorschläge:**
# Eine direktere Integration der Datensätze könnte die Effizienz verbessern. Erscheint jedoch Außerverhältnismäßig.
#
# **Nutzbare Formate für die automatisierte Verarbeitung:**
# CSV und JSON sind besonders gut geeignet, sie sind weit verbreitet und einfach zu handhaben.
#
# **Quelle:**<br>
# [Daten-BW Portal](https://www.daten-bw.de/) <br>
# [Daten-BW Portal Web Archive](https://web.archive.org/web/20240714142615/https://www.daten-bw.de/)
#
# ## GovData Portal
#
# **Verfügbare Datensätze:**
# Das GovData Portal bietet über 100.000 Datensätze aus Bereichen wie Bevölkerung, Gesundheit, Umwelt und Wissenschaft. Diese Daten sind in verschiedenen Formaten wie CSV, JSON, PDF und WMS verfügbar.
#
# **Verfügbare Datenformate:**
# Die Daten sind hauptsächlich im CSV-Format, aber auch JSON, PDF und WMS sind verfügbar.
#
# **Technisch nutzbare Schnittstellen:**
# GovData bietet eine gut dokumentierte API für den Metadatenkatalog, die eine einfache automatisierte Abfrage ermöglicht. Diese Schnittstelle unterstützt sowohl den Abruf einzelner Datensätze als auch ganzer Kataloge.
#
# **Durchsuchbarkeit und Navigation:**
# Die Navigation ist gut strukturiert und benutzerfreundlich. Die erweiterte Suche und die Kartensuche bieten zusätzliche Möglichkeiten, Datensätze schnell zu identifizieren und abzurufen.
#
# **Automatisierte Abfrage:**
# Die API ermöglicht eine einfache und effiziente automatisierte Abfrage der Daten. Sowohl einzelne Datensätze als auch komplette Kataloge können problemlos in BI-Systeme integriert werden.
#
# **Datenabruf:**
# Die Datensätze können einfach und schnell über die API oder die Weboberfläche abgerufen werden. Die gut strukturierte API und die klare Dokumentation erleichtern diesen Prozess erheblich.
#
# **Datenbeschreibung und -dokumentation:**
# Gleiche Struktur wie Daten-BW daher keine weiteren Anmerkung. Timestamps sind vorhanden, weitere Dokumentation ist auf der Open Data Portal Website der Gemeinde oder Stadt, welche Daten bereit gestellt hat.
#
# **Verbesserungsvorschläge:**
# Zusätzliche Dokumentation und API-Beispiele könnten die Nutzerfreundlichkeit weiter steigern, zum beispiel ein Link auf die Dokumentation des Open Data Portals wie bei Mannheim. Diese war direkt einsehbar im Portal von Mannheim und diese so wie weitere Dokumentationen könnten problemlos im Open Data Portal von GOVData integriert werden
#
# **Nutzbare Formate für die automatisierte Verarbeitung:**
# CSV und JSON sind gut geeignet. Diese Formate bieten eine hohe Flexibilität und Effizienz bei der Verarbeitung großer Datenmengen.
#
# **Quelle:**<br>
# [GovData Portal](https://www.govdata.de)<br>
# [GovData Portal Web Archive](https://web.archive.org/web/20240714142703/https://www.govdata.de/)
#
# ## Vergleich der drei Open Data Portale
#
# Grundsätzlich kann man sagen, dass das Portal von GOVData und Daten-BW sich in vielem sehr ähnelt, wenn nicht sogar gleicht. Dies verwundert auch nicht, da beide von der gleichen Firma, SEITENBAU GmbH, designt und realisiert wurden. Das Portal von Mannheim hingegen wurde höchstwahrscheinlich (Es wird vermutet, da das Unternehmen im Footer der Website neben den Nutzungsbedingungen und dem Impressum verlinkt ist. Allerdings wird nicht expliziet das Unternehmen darauf verwiesen, anders als es bei den Portalen GOVData und Daten-BW der Fall ist.) von der Firma [OpenDataSoft](https://web.archive.org/web/20240715084945/https://www.opendatasoft.com/en/) erstellt und bietet eine umfangreiche Auswahl an Datensätzen, die sich leicht durchsuchen und sortieren lassen. Die Navigation ist durchschnittlich und das Design zwar etwas veraltet, aber funktional. Die Daten umfassen viele städtische Bereiche und sind gut dokumentiert. Im Vergleich dazu sammelt das Portal von Daten-BW Daten aus verschiedenen Kommunen und Städten, was einen breiten Überblick ermöglicht. Jedoch ist der direkte Zugriff auf die Daten weniger effizient, da es sich hauptsächlich um eine Sammlung von Verweisen handelt. Die Daten sind gut strukturiert und dokumentiert, allerdings fehlt eine zentrale Spiegelung der Datensätze. Ähnlich wie Daten-BW bietet GOVData eine Sammlung von Daten aus verschiedenen Bundesländern und Datenbereitstellern. Die Struktur und Navigation sind benutzerfreundlich und ermöglichen eine effiziente Suche nach relevanten Datensätzen. Auch hier fehlt jedoch die direkte Spiegelung der Datensätze, was die automatisierte Nutzung erschwert.
#
# In Bezug auf die verfügbaren Datenformate sind die meisten Datensätze im Portal von Mannheim im CSV-Format verfügbar, was die Weiterverarbeitung erleichtert. Zusätzlich stehen auch andere Formate wie JSON und geografische Formate zur Verfügung, was eine flexible Nutzung der Daten ermöglicht. Daten-BW und GOVData bieten eine ähnliche Vielfalt an Datenformaten, einschließlich CSV, Excel und geografischen Formaten, was die Integration in verschiedene Systeme erleichtert.
#
# Hinsichtlich der technisch nutzbaren Schnittstellen bietet das Portal von Mannheim gut dokumentierte APIs, die sowohl den Abruf einzelner Datensätze als auch ganzer Datenkataloge ermöglichen. Dies erleichtert die Integration in BI-Systeme und die automatisierte Nutzung der Daten (siehe [API Konsole](https://mannheim.opendatasoft.com/api/explore/v2.1/console)). Im Gegensatz dazu bieten Daten-BW und GOVData keine eigenen APIs, sondern verweisen auf die Schnittstellen der einzelnen Kommunen und Städte. Dies macht die automatisierte Nutzung der Daten etwas umständlicher, da zusätzliche Schritte erforderlich sind, um die relevanten Schnittstellen zu finden und zu nutzen.
#
# Zusammenfassend lässt sich sagen, dass alle drei Portale eine breite Auswahl an Datensätzen und Datenformaten bieten. Mannheim sticht durch seine direkte API und die zentrale Bereitstellung der Datensätze hervor, während Daten-BW und GOVData durch ihre umfangreiche Sammlung von Daten aus verschiedenen Regionen punkten, jedoch in der direkten automatisierten Nutzung der Daten etwas hinter Mannheim zurückbleiben.
#
# **Quelle:**<br>
# [GOVData Impressum](https://web.archive.org/web/20240715083528/https://www.govdata.de/web/guest/impressum)<br>
# [Daten-BW Impressum](https://web.archive.org/web/20240715084627/https://www.daten-bw.de/web/guest/impressum)<br>
# [Stadt Mannheim Open Data Portal](https://web.archive.org/web/20240715084807/https://mannheim.opendatasoft.com/terms/terms-and-conditions/)<br>

# %% [markdown]
# # Aufgabe 2: Vergleich von Fahrradzählstellen
#
#
# In diesem Teil des Notebooks analysieren wir Fahrradzähldaten aus zwei verschiedenen Städten: Konstanz und Freiburg. Die Daten werden von den folgenden Quellen bezogen:
#
# 1. **Konstanz**: [Zählstelle Herose 2021](https://offenedaten-konstanz.de/sites/default/files/Zaehlstelle_Herose_2021_15min_3.csv)/ [Archive-Link](https://web.archive.org/web/20240714153903/https://offenedaten-konstanz.de/dataset/fahrrad-dauerz-hlstellen/resource/30d361a1-2a24-4a75-a98e-4ca3106a494e#{})
# 2. **Freiburg**: [Fahrradzählstellen Zeitreihe](https://fritz.freiburg.de:8443/duva2dcat/dataset/de-bw-freiburg-fahrrad-zaehlstellen_zeitreihe/content.csv)/ [Archive-Link](https://web.archive.org/web/20240714154049/https://www.daten-bw.de/web/guest/suchen/-/details/fahrrad-zahlstellen-zeitreihe)
#
# Wir werden die Daten herunterladen, aufbereiten, visualisieren und vergleichen.
#
# ## Schritt 1: Einlesen der Daten
# Im ersten Schritt laden wir die Datensätze herunter und lesen sie in Pandas DataFrames ein. Dies ermöglicht uns eine einfache und effiziente Datenmanipulation und Analyse.

# %%
import pandas as pd

# URLs der Datensätze
url_konstanz = 'https://offenedaten-konstanz.de/sites/default/files/Zaehlstelle_Herose_2021_15min_3.csv'
url_freiburg = 'https://fritz.freiburg.de:8443/duva2dcat/dataset/de-bw-freiburg-fahrrad-zaehlstellen_zeitreihe/content.csv'

# Einlesen der Datensätze
data_konstanz = pd.read_csv(url_konstanz, delimiter=';')
data_freiburg = pd.read_csv(url_freiburg)

# Anzeigen einer Stichprobe von fünf Zeilen beider Datensätze
print("Konstanz Datensatz:\n", data_konstanz.head())
print("Freiburg Datensatz:\n", data_freiburg.head())
# Out:
# Konstanz Datensatz:
#                 Zeit  Fahrradbruecke  Fahrradbruecke stadteinwaerts  \
# 0  01.01.2021 00:00             0.0                            0.0
# 1  01.01.2021 00:15             2.0                            1.0
# 2  01.01.2021 00:30             0.0                            0.0
# 3  01.01.2021 00:45             2.0                            1.0
# 4  01.01.2021 01:00             2.0                            1.0
#
#    Fahrradbruecke stadtauswaerts  \
# 0                            0.0
# 1                            1.0
# 2                            0.0
# 3                            1.0
# 4                            1.0
#
#                                             Quelle
# 0  Stadt Konstanz, Amt für Stadtplanung und Umwelt
# 1  Stadt Konstanz, Amt für Stadtplanung und Umwelt
# 2  Stadt Konstanz, Amt für Stadtplanung und Umwelt
# 3  Stadt Konstanz, Amt für Stadtplanung und Umwelt
# 4  Stadt Konstanz, Amt für Stadtplanung und Umwelt
# Freiburg Datensatz:
# ...

# %% [markdown]
# In diesem Schritt laden wir die Datensätze von den angegebenen URLs herunter und lesen sie in Pandas DataFrames ein. Dies ermöglicht uns eine einfache und effiziente Datenmanipulation und Analyse.
#
# Wir verwenden die `pd.read_csv` Funktion von Pandas, um die CSV-Dateien einzulesen. Für den Datensatz aus Konstanz geben wir den `delimiter=';'` an, da die Werte durch Semikolons getrennt sind. Für den Freiburger Datensatz ist keine spezielle Angabe notwendig, da die Werte durch Kommata getrennt sind.
#
# Nachdem die Daten erfolgreich eingelesen wurden, zeigen wir die ersten fünf Zeilen jedes Datensatzes an, um die Struktur und den Inhalt der Daten zu überprüfen.

# %% [markdown]
# ## Schritt 2: Datenaufbereitung
#
# In diesem Schritt bereiten wir die Daten auf, indem wir sie bereinigen und die notwendigen Transformationen durchführen. Dies umfasst die Konvertierung von Datums- und Zeitspalten in ein geeignetes Format und das Entfernen von fehlenden Werten.

# %%
# Konstanz-Datensatz aufbereiten
data_konstanz['Zeit'] = pd.to_datetime(data_konstanz['Zeit'], format='%d.%m.%Y %H:%M')
data_konstanz['Fahrradbruecke'] = pd.to_numeric(data_konstanz['Fahrradbruecke'], errors='coerce')
data_konstanz['Fahrradbruecke stadteinwaerts'] = pd.to_numeric(data_konstanz['Fahrradbruecke stadteinwaerts'], errors='coerce')
data_konstanz['Fahrradbruecke stadtauswaerts'] = pd.to_numeric(data_konstanz['Fahrradbruecke stadtauswaerts'], errors='coerce')
data_konstanz.dropna(inplace=True)

# Sicherstellen, dass die Datetime-Spalte im Freiburger Datensatz im datetime-Format vorliegt
data_freiburg['Datetime'] = pd.to_datetime(data_freiburg['Datetime'])
data_freiburg['Anzahl Fahrräder'] = pd.to_numeric(data_freiburg['Anzahl Fahrräder'], errors='coerce')
data_freiburg.dropna(inplace=True)

# Anzeigen der aufbereiteten Daten
print("Aufbereiteter Konstanz Datensatz:\n", data_konstanz.head())
print("Aufbereiteter Freiburg Datensatz:\n", data_freiburg.head())
# Out:
# Aufbereiteter Konstanz Datensatz:
#                   Zeit  Fahrradbruecke  Fahrradbruecke stadteinwaerts  \
# 0 2021-01-01 00:00:00             0.0                            0.0
# 1 2021-01-01 00:15:00             2.0                            1.0
# 2 2021-01-01 00:30:00             0.0                            0.0
# 3 2021-01-01 00:45:00             2.0                            1.0
# 4 2021-01-01 01:00:00             2.0                            1.0
#
#    Fahrradbruecke stadtauswaerts  \
# 0                            0.0
# 1                            1.0
# 2                            0.0
# 3                            1.0
# 4                            1.0
#
#                                             Quelle
# 0  Stadt Konstanz, Amt für Stadtplanung und Umwelt
# 1  Stadt Konstanz, Amt für Stadtplanung und Umwelt
# 2  Stadt Konstanz, Amt für Stadtplanung und Umwelt
# 3  Stadt Konstanz, Amt für Stadtplanung und Umwelt
# ...

# %% [markdown]
# In diesem Schritt bereiten wir die Daten auf, indem wir die Datums- und Zeitspalten in ein geeignetes Format konvertieren und fehlende Werte entfernen. Dies ist notwendig, um die Daten für die nachfolgenden Analysen und Visualisierungen vorzubereiten.
#
# ### Konstanz-Datensatz
#
# 1. **Konvertierung der "Zeit"-Spalte**: Wir konvertieren die "Zeit"-Spalte in ein datetime-Format.
# 2. **Bereinigung der Daten**: Wir entfernen alle Zeilen mit fehlenden Werten.
#
# ### Freiburg-Datensatz
#
# 1. **Erstellen einer neuen "Datetime"-Spalte**: Wir kombinieren die "Datum" und "Stunde"-Spalten und konvertieren sie in ein datetime-Format.
# 2. **Bereinigung der Daten**: Wir entfernen alle Zeilen mit fehlenden Werten.
#
# Nachdem die Daten erfolgreich aufbereitet wurden, zeigen wir die ersten fünf Zeilen jedes Datensatzes an, um die Aufbereitung zu überprüfen.

# %% [markdown]
# ## Schritt 3: Visualisierung der Zeitreihen
#
# In diesem Schritt erstellen wir einfache Plots für beide Zeitreihen. Dies ermöglicht uns, Trends und Muster in den Fahrradzähldaten für die beiden Städte Konstanz und Freiburg zu erkennen.

# %%
import matplotlib.pyplot as plt

# Konstanz-Datensatz plotten
plt.figure(figsize=(12, 6))
plt.plot(data_konstanz['Zeit'], data_konstanz['Fahrradbruecke'], label='Fahrrad Count')
plt.xlabel('Zeit')
plt.ylabel('Anzahl Fahrräder')
plt.title('Fahrradzählungen in Konstanz 2021')
plt.legend()
plt.show()

# Freiburg-Datensatz plotten
plt.figure(figsize=(12, 6))
plt.plot(data_freiburg['Datetime'], data_freiburg['Anzahl Fahrräder'], label='Fahrrad Count')
plt.xlabel('Zeit')
plt.ylabel('Anzahl Fahrräder')
plt.title('Fahrradzählungen in Freiburg 2021')
plt.legend()
plt.show()

# %% [markdown]
# In diesem Schritt erstellen wir einfache Plots für beide Zeitreihen. Dies ermöglicht uns, Trends und Muster in den Fahrradzähldaten für die beiden Städte Konstanz und Freiburg zu erkennen.
#
# ### Konstanz-Datensatz
#
# Wir plotten die Anzahl der Fahrräder, die an der Fahrradbrücke insgesamt, stadteinwärts und stadtauswärts gezählt wurden, gegen die Zeit.
#
# ### Freiburg-Datensatz
#
# Wir plotten die Anzahl der Fahrräder, die an der Zählstelle in Freiburg gezählt wurden, gegen die Zeit.

# %% [markdown]
# ## Schritt 4: Monatliche Aggregation und Vergleich
#
# In diesem Schritt aggregieren wir die Daten monatsweise für die Monate des Jahres 2021 und stellen die beiden Städte Konstanz und Freiburg gegenüber. Dies ermöglicht uns, die Fahrradzähldaten der beiden Städte auf monatlicher Basis zu vergleichen.

# %%
# Konstanz-Daten monatlich aggregieren
data_konstanz['Monat'] = data_konstanz['Zeit'].dt.to_period('M')
monthly_konstanz = data_konstanz.groupby('Monat')['Fahrradbruecke'].sum().reset_index()

# Freiburg-Daten monatlich aggregieren
data_freiburg['Monat'] = data_freiburg['Datetime'].dt.to_period('M')
monthly_freiburg = data_freiburg.groupby('Monat')['Anzahl Fahrräder'].sum().reset_index()

# Daten für das Jahr 2021 filtern
monthly_konstanz_2021 = monthly_konstanz[(monthly_konstanz['Monat'] >= '2021-01') & (monthly_konstanz['Monat'] <= '2021-12')]
monthly_freiburg_2021 = monthly_freiburg[(monthly_freiburg['Monat'] >= '2021-01') & (monthly_freiburg['Monat'] <= '2021-12')]

# Konvertierung der Werte zu Integern
monthly_konstanz_2021['Fahrradbruecke'] = monthly_konstanz_2021['Fahrradbruecke'].astype(int)
monthly_freiburg_2021['Anzahl Fahrräder'] = monthly_freiburg_2021['Anzahl Fahrräder'].astype(int)

# Überprüfen der aggregierten Daten
print("Monatlich aggregierte Daten für Konstanz 2021:\n", monthly_konstanz_2021)
print("Monatlich aggregierte Daten für Freiburg 2021:\n", monthly_freiburg_2021)

# Vergleich der beiden Städte plotten
plt.figure(figsize=(12, 6))
plt.plot(monthly_konstanz_2021['Monat'].astype(str), monthly_konstanz_2021['Fahrradbruecke'], label='Konstanz Gesamt')
plt.plot(monthly_freiburg_2021['Monat'].astype(str), monthly_freiburg_2021['Anzahl Fahrräder'], label='Freiburg Gesamt')
plt.xlabel('Monat')
plt.ylabel('Anzahl Fahrräder')
plt.title('Monatliche Fahrradzählungen: Konstanz vs. Freiburg 2021')
plt.legend()
plt.show()
# Out:
# Monatlich aggregierte Daten für Konstanz 2021:
#        Monat  Fahrradbruecke
# 0   2021-01           92336
# 1   2021-02          156459
# 2   2021-03          250772
# 3   2021-04          254226
# 4   2021-05          207524
# 5   2021-06          312690
# 6   2021-07          341312
# 7   2021-08          220291
# 8   2021-09            6397
# 9   2021-10          299548
# 10  2021-11          240458
# 11  2021-12          188443
# Monatlich aggregierte Daten für Freiburg 2021:
#        Monat  Anzahl Fahrräder
# 72  2021-01            281209
# 73  2021-02            384038
# 74  2021-03            539441
# 75  2021-04            561473
# 76  2021-05            583846
# 77  2021-06            771174
# 78  2021-07            876785
# 79  2021-08            627188
# 80  2021-09            763815
# 81  2021-10            775483
# 82  2021-11            629426
# 83  2021-12            494277
# C:\Users\kleme\AppData\Local\Temp\ipykernel_15192\4087794250.py:15: SettingWithCopyWarning:
# ...

# %% [markdown]
# In diesem Schritt aggregieren wir die Daten monatsweise für die Monate des Jahres 2021 und stellen die beiden Städte Konstanz und Freiburg gegenüber. Dies ermöglicht uns, die Fahrradzähldaten der beiden Städte auf monatlicher Basis zu vergleichen.
#
# ### Konstanz-Datensatz
#
# Wir aggregieren die Daten der Stadt Konstanz auf monatlicher Basis und filtern die Daten für das Jahr 2021. Dabei summieren wir die Anzahl der Fahrräder, die an der Fahrradbruecke insgesamt gezählt wurden.
#
# ### Freiburg-Datensatz
#
# Wir aggregieren die Daten der Stadt Freiburg auf monatlicher Basis und filtern die Daten für das Jahr 2021. Dabei summieren wir die Anzahl der Fahrräder, die an der Zählstelle in Freiburg gezählt wurden.
#
# ### Vergleich der beiden Städte
#
# Wir stellen die monatlich aggregierten Daten der beiden Städte gegenüber und plotten die Ergebnisse, um die Unterschiede und Ähnlichkeiten in den Fahrradzähldaten zu visualisieren.

# %% [markdown]
# ## Schlussfolgerung
#
# In diesem Projekt haben wir Fahrradzähldaten aus zwei verschiedenen Städten, Konstanz und Freiburg, analysiert und verglichen. Der gesamte Prozess wurde in vier Hauptschritten durchgeführt:
#
# 1. **Einlesen der Daten**: Wir haben die Fahrradzähldaten für beide Städte aus öffentlichen Datenquellen heruntergeladen und in Pandas DataFrames eingelesen.
# 2. **Datenaufbereitung**: Wir haben die Daten bereinigt und die Datums- und Zeitspalten in geeignete Formate konvertiert, um sie für die Analyse vorzubereiten.
# 3. **Visualisierung der Zeitreihen**: Wir haben einfache Plots der Zeitreihen für beide Städte erstellt, um Trends und Muster in den Fahrradzähldaten zu erkennen.
# 4. **Monatliche Aggregation und Vergleich**: Wir haben die Daten monatsweise für das Jahr 2021 aggregiert und die Fahrradzähldaten der beiden Städte gegenübergestellt.
#
# Durch diese Schritte konnten wir interessante Unterschiede und Gemeinsamkeiten in den Fahrradzähldaten von Konstanz und Freiburg aufdecken. Insbesondere zeigte sich, dass Freiburg insgesamt höhere Fahrradzahlen aufweist als Konstanz, wobei beide Städte saisonale Muster in den Daten aufwiesen.
#
# ## Fazit
# Es wurde versucht, die Daten zu bereinigen und vergleichbar zu machen. Der erstellte Plot liefert einen guten Vergleich der Fahrradzähldaten zwischen Konstanz und Freiburg. Ein Anstieg der Fahrradfahrenden ab Mai/Juni ist durchaus plausibel, da dies mit der wärmeren Jahreszeit korreliert. Zu beachten ist, dass Konstanz mehrere Fahrradzählstellen hat und in diesem Projekt lediglich einer der genutzten Datensätze von Konstanz verwendet wurde. Daher ist dieser Datensatz nicht vollständig repräsentativ für die gesamte Region Konstanz.
